# %% [markdown]
# # Lab | Hypothesis Testing

# %% [markdown]
# **Objective**
#
# Welcome to the Hypothesis Testing Lab, where we embark on an enlightening journey through the realm of statistical decision-making! In this laboratory, we delve into various scenarios, applying the powerful tools of hypothesis testing to scrutinize and interpret data.
#
# From testing the mean of a single sample (One Sample T-Test), to investigating differences between independent groups (Two Sample T-Test), and exploring relationships within dependent samples (Paired Sample T-Test), our exploration knows no bounds. Furthermore, we'll venture into the realm of Analysis of Variance (ANOVA), unraveling the complexities of comparing means across multiple groups.
#
# So, grab your statistical tools, prepare your hypotheses, and let's embark on this fascinating journey of exploration and discovery in the world of hypothesis testing!

# %% [markdown]
# **Challenge 1**

# %% [markdown]
# In this challenge, we will be working with pokemon data. The data can be found here:
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv

# %%
#libraries
import pandas as pd
import scipy.stats as st
import numpy as np
from math import sqrt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv")
df.head(50)
# Out:
#                 Name    Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0          Bulbasaur     Grass  Poison   45      49       49       65
# 1            Ivysaur     Grass  Poison   60      62       63       80
# 2           Venusaur     Grass  Poison   80      82       83      100
# 3      Mega Venusaur     Grass  Poison   80     100      123      122
# 4         Charmander      Fire     NaN   39      52       43       60
# 5         Charmeleon      Fire     NaN   58      64       58       80
# 6          Charizard      Fire  Flying   78      84       78      109
# 7   Mega Charizard X      Fire  Dragon   78     130      111      130
# 8   Mega Charizard Y      Fire  Flying   78     104       78      159
# 9           Squirtle     Water     NaN   44      48       65       50
# 10         Wartortle     Water     NaN   59      63       80       65
# 11         Blastoise     Water     NaN   79      83      100       85
# 12    Mega Blastoise     Water     NaN   79     103      120      135
# 13          Caterpie       Bug     NaN   45      30       35       20
# 14           Metapod       Bug     NaN   50      20       55       25
# 15        Butterfree       Bug  Flying   60      45       50       90
# 16            Weedle       Bug  Poison   40      35       30       20
# 17            Kakuna       Bug  Poison   45      25       50       25
# 18          Beedrill       Bug  Poison   65      90       40       45
# 19     Mega Beedrill       Bug  Poison   65     150       40       15
# 20            Pidgey    Normal  Flying   40      45       40       35
# 21         Pidgeotto    Normal  Flying   63      60       55       50
# 22           Pidgeot    Normal  Flying   83      80       75       70
# 23      Mega Pidgeot    Normal  Flying   83      80       80      135
# 24           Rattata    Normal     NaN   30      56       35       25
# 25          Raticate    Normal     NaN   55      81       60       50
# 26           Spearow    Normal  Flying   40      60       30       31
# 27            Fearow    Normal  Flying   65      90       65       61
# 28             Ekans    Poison     NaN   35      60       44       40
# 29             Arbok    Poison     NaN   60      85       69       65
# 30           Pikachu  Electric     NaN   35      55       40       50
# 31            Raichu  Electric     NaN   60      90       55       90
# 32         Sandshrew    Ground     NaN   50      75       85       20
# 33         Sandslash    Ground     NaN   75     100      110       45
# 34          Nidoran♀    Poison     NaN   55      47       52       40
# 35          Nidorina    Poison     NaN   70      62       67       55
# 36         Nidoqueen    Poison  Ground   90      92       87       75
# 37          Nidoran♂    Poison     NaN   46      57       40       40
# 38          Nidorino    Poison     NaN   61      72       57       55
# 39          Nidoking    Poison  Ground   81     102       77       85
# 40          Clefairy     Fairy     NaN   70      45       48       60
# 41          Clefable     Fairy     NaN   95      70       73       95
# 42            Vulpix      Fire     NaN   38      41       40       50
# 43         Ninetales      Fire     NaN   73      76       75       81
# 44        Jigglypuff    Normal   Fairy  115      45       20       45
# 45        Wigglytuff    Normal   Fairy  140      70       45       85
# 46             Zubat    Poison  Flying   40      45       35       30
# 47            Golbat    Poison  Flying   75      80       70       65
# 48            Oddish     Grass  Poison   45      50       55       75
# 49             Gloom     Grass  Poison   60      65       70       85
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# 2       100     80           1      False
# 3       120     80           1      False
# 4        50     65           1      False
# 5        65     80           1      False
# 6        85    100           1      False
# 7        85    100           1      False
# 8       115    100           1      False
# 9        64     43           1      False
# 10       80     58           1      False
# 11      105     78           1      False
# 12      115     78           1      False
# 13       20     45           1      False
# 14       25     30           1      False
# 15       80     70           1      False
# 16       20     50           1      False
# 17       25     35           1      False
# 18       80     75           1      False
# 19       80    145           1      False
# 20       35     56           1      False
# 21       50     71           1      False
# 22       70    101           1      False
# 23       80    121           1      False
# 24       35     72           1      False
# 25       70     97           1      False
# 26       31     70           1      False
# 27       61    100           1      False
# 28       54     55           1      False
# 29       79     80           1      False
# 30       50     90           1      False
# 31       80    110           1      False
# 32       30     40           1      False
# 33       55     65           1      False
# 34       40     41           1      False
# 35       55     56           1      False
# 36       85     76           1      False
# 37       40     50           1      False
# 38       55     65           1      False
# 39       75     85           1      False
# 40       65     35           1      False
# 41       90     60           1      False
# 42       65     65           1      False
# 43      100    100           1      False
# 44       25     20           1      False
# 45       50     45           1      False
# 46       40     55           1      False
# 47       75     90           1      False
# 48       65     30           1      False
# 49       75     40           1      False

# %% [markdown]
# - We posit that Pokemons of type Dragon have, on average, more HP stats than Grass. Choose the propper test and, with 5% significance, comment your findings.

# %%
#code here
#H0 : Pokemon of type Dragon have on average <= HP than Pokemon of type Grass
#H1 : Pokemon of type Dragon have on average > HP than Pokemon of type Grass

alpha = 0.05

# %%
df["Type 1"].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
df["Type 2"].value_counts()
# Out:
# Type 2
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: count, dtype: int64

# %%
dragon_df = df[(df["Type 1"] == "Dragon") | (df["Type 2"] == "Dragon")]
dragon_df
# Out:
#                        Name    Type 1    Type 2   HP  Attack  Defense  \
# 7          Mega Charizard X      Fire    Dragon   78     130      111
# 159                 Dratini    Dragon       NaN   41      64       45
# 160               Dragonair    Dragon       NaN   61      84       65
# 161               Dragonite    Dragon    Flying   91     134       95
# 196           Mega Ampharos  Electric    Dragon   90      95      105
# 249                 Kingdra     Water    Dragon   75      95       95
# 275           Mega Sceptile     Grass    Dragon   70     110       75
# 360                 Vibrava    Ground    Dragon   50      70       50
# 361                  Flygon    Ground    Dragon   80     100       80
# 365                 Altaria    Dragon    Flying   75      70       90
# 366            Mega Altaria    Dragon     Fairy   75     110      110
# 406                   Bagon    Dragon       NaN   45      75       60
# 407                 Shelgon    Dragon       NaN   65      95      100
# 408               Salamence    Dragon    Flying   95     135       80
# 409          Mega Salamence    Dragon    Flying   95     145      130
# 417                  Latias    Dragon   Psychic   80      80       90
# 418             Mega Latias    Dragon   Psychic   80     100      120
# 419                  Latios    Dragon   Psychic   80      90       80
# 420             Mega Latios    Dragon   Psychic   80     130      100
# 425                Rayquaza    Dragon    Flying  105     150       90
# 426           Mega Rayquaza    Dragon    Flying  105     180      100
# 491                   Gible    Dragon    Ground   58      70       45
# 492                  Gabite    Dragon    Ground   68      90       65
# 493                Garchomp    Dragon    Ground  108     130       95
# 494           Mega Garchomp    Dragon    Ground  108     170      115
# 540                  Dialga     Steel    Dragon  100     120      120
# 541                  Palkia     Water    Dragon   90     120      100
# 544  Giratina Altered Forme     Ghost    Dragon  150     100      120
# 545   Giratina Origin Forme     Ghost    Dragon  150     120      100
# 671                    Axew    Dragon       NaN   46      87       60
# 672                 Fraxure    Dragon       NaN   66     117       70
# 673                 Haxorus    Dragon       NaN   76     147       90
# 682               Druddigon    Dragon       NaN   77     120       90
# 694                   Deino      Dark    Dragon   52      65       50
# 695                Zweilous      Dark    Dragon   72      85       70
# 696               Hydreigon      Dark    Dragon   92     105       90
# 706                Reshiram    Dragon      Fire  100     120      100
# 707                  Zekrom    Dragon  Electric  100     150      120
# 710                  Kyurem    Dragon       Ice  125     130       90
# 711     Kyurem Black Kyurem    Dragon       Ice  125     170      100
# 712     Kyurem White Kyurem    Dragon       Ice  125     120       90
# 761                Dragalge    Poison    Dragon   65      75       90
# 766                  Tyrunt      Rock    Dragon   58      89       77
# 767               Tyrantrum      Rock    Dragon   82     121      119
# 774                   Goomy    Dragon       NaN   45      50       35
# 775                 Sliggoo    Dragon       NaN   68      75       53
# 776                  Goodra    Dragon       NaN   90     100       70
# 790                  Noibat    Flying    Dragon   40      30       35
# 791                 Noivern    Flying    Dragon   85      70       80
# 794      Zygarde Half Forme    Dragon    Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 7        130       85    100           1      False
# 159       50       50     50           1      False
# 160       70       70     70           1      False
# 161      100      100     80           1      False
# 196      165      110     45           2      False
# 249       95       95     85           2      False
# 275      145       85    145           3      False
# 360       50       50     70           3      False
# 361       80       80    100           3      False
# 365       70      105     80           3      False
# 366      110      105     80           3      False
# 406       40       30     50           3      False
# 407       60       50     50           3      False
# 408      110       80    100           3      False
# 409      120       90    120           3      False
# 417      110      130    110           3       True
# 418      140      150    110           3       True
# 419      130      110    110           3       True
# 420      160      120    110           3       True
# 425      150       90     95           3       True
# 426      180      100    115           3       True
# 491       40       45     42           4      False
# 492       50       55     82           4      False
# 493       80       85    102           4      False
# 494      120       95     92           4      False
# 540      150      100     90           4       True
# 541      150      120    100           4       True
# 544      100      120     90           4       True
# 545      120      100     90           4       True
# 671       30       40     57           5      False
# 672       40       50     67           5      False
# 673       60       70     97           5      False
# 682       60       90     48           5      False
# 694       45       50     38           5      False
# 695       65       70     58           5      False
# 696      125       90     98           5      False
# 706      150      120     90           5       True
# 707      120      100     90           5       True
# 710      130       90     95           5       True
# 711      120       90     95           5       True
# 712      170      100     95           5       True
# 761       97      123     44           6      False
# 766       45       45     48           6      False
# 767       69       59     71           6      False
# 774       55       75     40           6      False
# 775       83      113     60           6      False
# 776      110      150     80           6      False
# 790       45       40     55           6      False
# 791       97       80    123           6      False
# 794       81       95     95           6       True

# %%
dragon_grass = dragon_df[(dragon_df["Type 1"] == "Grass") | (dragon_df["Type 2"] == "Grass")]
dragon_grass
# Out:
#               Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 275  Mega Sceptile  Grass  Dragon  70     110       75      145       85
#
#      Speed  Generation  Legendary
# 275    145           3      False

# %%
grass_df = df[(df["Type 1"] == "Grass") | (df["Type 2"] == "Grass")]
grass_df
# Out:
#                        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                 Bulbasaur  Grass  Poison  45      49       49       65
# 1                   Ivysaur  Grass  Poison  60      62       63       80
# 2                  Venusaur  Grass  Poison  80      82       83      100
# 3             Mega Venusaur  Grass  Poison  80     100      123      122
# 48                   Oddish  Grass  Poison  45      50       55       75
# ..                      ...    ...     ...  ..     ...      ...      ...
# 783    Pumpkaboo Super Size  Ghost   Grass  59      66       70       44
# 784  Gourgeist Average Size  Ghost   Grass  65      90      122       58
# 785    Gourgeist Small Size  Ghost   Grass  55      85      122       58
# 786    Gourgeist Large Size  Ghost   Grass  75      95      122       58
# 787    Gourgeist Super Size  Ghost   Grass  85     100      122       58
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# 1         80     60           1      False
# 2        100     80           1      False
# 3        120     80           1      False
# 48        65     30           1      False
# ..       ...    ...         ...        ...
# 783       55     41           6      False
# 784       75     84           6      False
# 785       75     99           6      False
# 786       75     69           6      False
# 787       75     54           6      False
#
# [95 rows x 11 columns]

# %%
grass_dragon = grass_df[(grass_df["Type 1"] == "Dragon") | (grass_df["Type 2"] == "Dragon")]
grass_dragon
# Out:
#               Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 275  Mega Sceptile  Grass  Dragon  70     110       75      145       85
#
#      Speed  Generation  Legendary
# 275    145           3      False

# %%
#code here
#H0 : Pokemon of type Dragon have on average <= HP than Pokemon of type Grass
#H1 : Pokemon of type Dragon have on average > HP than Pokemon of type Grass

alpha = 0.05

# %%
dragon_df_hp = dragon_df["HP"]

# %%
grass_df_hp = grass_df["HP"]

# %%
dragon_df_hp.mean()
# Out:
# 82.9

# %%
grass_df_hp.mean()
# Out:
# 66.05263157894737

# %%
st.ttest_ind(dragon_df_hp, grass_df_hp, equal_var=False, alternative = "greater")
# Out:
# TtestResult(statistic=4.097528915272702, pvalue=5.0907690611769255e-05, df=77.58086781513519)

# %% [markdown]
# We reject the null-Hypothesis that Pokemon of Type Draon have less or equal as much HP as Pokemon of Type Grass!

# %% [markdown]
# - We posit that Legendary Pokemons have different stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) when comparing with Non-Legendary. Choose the propper test and, with 5% significance, comment your findings.

# %% [markdown]
# H0 : Legendary Pokemon have the same stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) as non-legendary Pokemon
# H1 : Legendary Pokemon have different stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) than non-legendary Pokemon

# %%
alpha = 0.05

# %%
stats = ["HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"]

# %%
legendary_df = df[df["Legendary"] == True]
non_legendary_df = df[df["Legendary"] == False]

# %%
legendary_df.describe()
# Out:
#                HP      Attack     Defense     Sp. Atk     Sp. Def       Speed  \
# count   65.000000   65.000000   65.000000   65.000000   65.000000   65.000000
# mean    92.738462  116.676923   99.661538  122.184615  105.938462  100.184615
# std     21.722164   30.348037   28.255131   31.104608   28.827004   22.952323
# min     50.000000   50.000000   20.000000   50.000000   20.000000   50.000000
# 25%     80.000000  100.000000   90.000000  100.000000   90.000000   90.000000
# 50%     91.000000  110.000000  100.000000  120.000000  100.000000  100.000000
# 75%    105.000000  131.000000  115.000000  150.000000  120.000000  110.000000
# max    150.000000  190.000000  200.000000  194.000000  200.000000  180.000000
#
#        Generation
# count   65.000000
# mean     3.769231
# std      1.455262
# min      1.000000
# 25%      3.000000
# 50%      4.000000
# 75%      5.000000
# max      6.000000

# %%
non_legendary_df.describe()
# Out:
#                HP      Attack     Defense     Sp. Atk     Sp. Def       Speed  \
# count  735.000000  735.000000  735.000000  735.000000  735.000000  735.000000
# mean    67.182313   75.669388   71.559184   68.454422   68.892517   65.455782
# std     24.808849   30.490153   30.408194   29.091705   25.669310   27.843038
# min      1.000000    5.000000    5.000000   10.000000   20.000000    5.000000
# 25%     50.000000   54.500000   50.000000   45.000000   50.000000   45.000000
# 50%     65.000000   72.000000   66.000000   65.000000   65.000000   64.000000
# 75%     79.500000   95.000000   85.000000   85.000000   85.000000   85.000000
# max    255.000000  185.000000  230.000000  175.000000  230.000000  160.000000
#
#        Generation
# count  735.000000
# mean     3.284354
# std      1.673471
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      5.000000
# max      6.000000

# %%
# List of stat columns to analyze
stats = ["HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"]

# Perform t-test for each stat
t_test_results = {}
for stat in stats:
    t_stat, p_value = st.ttest_ind(legendary_df[stat], non_legendary_df[stat])
    t_test_results[stat] = p_value

# Output p-values for each stat
print(t_test_results)
# Out:
# {'HP': 3.3306476848461913e-15, 'Attack': 7.827253003205333e-24, 'Defense': 1.5842226094427255e-12, 'Sp. Atk': 6.314915770427265e-41, 'Sp. Def': 1.8439809580409597e-26, 'Speed': 2.3540754436898437e-21}

# %% [markdown]
# Since each p-value for every stat comparing legendary to non-legendary is lower than our alpha, we can reject the null-hypothesis!

# %% [markdown]
# **Challenge 2**

# %% [markdown]
# In this challenge, we will be working with california-housing data. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# **We posit that houses close to either a school or a hospital are more expensive.**
#
# - School coordinates (-118, 37)
# - Hospital coordinates (-122, 34)
#
# We consider a house (neighborhood) to be close to a school or hospital if the distance is lower than 0.50.
#
# Hint:
# - Write a function to calculate euclidean distance from each house (neighborhood) to the school and to the hospital.
# - Divide your dataset into houses close and far from either a hospital or school.
# - Choose the propper test and, with 5% significance, comment your findings.

# %%
def calculate_distance (df):
    """
    A(lon1,lat1)
    B(lon2,lat2)
    d(A,B) = sqr((lon2-lon1)**2+(lat2-lat1)**2)
    
    cast a new column with euc distance
    """
    S_coord = (-118, 37)
    H_coord = (-122, 34)

    df["school_dist"] = 0.0
    df["hospital_dist"] = 0.0
    
    for index, row in df.iterrows():
        d_s = sqrt((row["longitude"]-S_coord[0])**2+(row["latitude"]-S_coord[1])**2)
        d_h = sqrt((row["longitude"]-H_coord[0])**2+(row["latitude"]-H_coord[1])**2)
        
        df.at[index, "school_dist"] = float(d_s)  # Ensure it's a float
        df.at[index, "hospital_dist"] = float(d_h)  # Ensure it's a float
    return df

# %%
print(df.columns)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4523    -118.05     36.64                34.0       2090.0           478.0
# 5596    -118.18     37.35                16.0       3806.0           794.0
# 5597    -118.18     36.63                23.0       2311.0           487.0
# 6776    -118.30     37.17                22.0       3480.0           673.0
# 6904    -118.31     36.94                35.0       2563.0           530.0
#
#       population  households  median_income  median_house_value  school_dist  \
# 4523       896.0       426.0         2.0357             74200.0     0.363456
# 5596      1501.0       714.0         2.1212            108300.0     0.393573
# 5597      1019.0       384.0         2.2574            104700.0     0.411461
# 6776      1541.0       636.0         2.7500             94500.0     0.344819
# 6904       861.0       371.0         2.3250             80600.0     0.315753
#
#       hospital_dist
# 4523       4.751010
# 5596       5.080837
# 5597       4.637812
# 6776       4.872258
# 6904       4.718019

# %%
df_far = df2[(df2["school_dist"]>0.5)|(df2["hospital_dist"]>0.5)]
df_far
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value  school_dist  \
# 0          1015.0       472.0         1.4936             66900.0     4.638125
# 1          1129.0       463.0         1.8200             80100.0     4.384165
# 2           333.0       117.0         1.6509             85700.0     4.773856
# 3           515.0       226.0         3.1917             73400.0     4.801510
# 4           624.0       262.0         1.9250             65500.0     4.850753
# ...           ...         ...            ...                 ...          ...
# 16995       907.0       369.0         2.3571            111400.0     7.211380
# 16996      1194.0       465.0         2.5179             79000.0     7.275232
# 16997      1244.0       456.0         3.0313            103600.0     7.944533
# 16998      1298.0       478.0         1.9797             85800.0     7.920227
# 16999       806.0       270.0         3.0147             94600.0     7.270083
#
#        hospital_dist
# 0           7.692347
# 1           7.540617
# 2           7.446456
# 3           7.438716
# 4           7.442432
# ...              ...
# 16995       6.957298
# 16996       7.064630
# 16997       8.170410
# 16998       8.132035
# 16999       6.949396
#
# [17000 rows x 11 columns]

# %%
df_close["median_house_value"].describe()
# Out:
# count         5.000000
# mean      92460.000000
# std       14823.730974
# min       74200.000000
# 25%       80600.000000
# 50%       94500.000000
# 75%      104700.000000
# max      108300.000000
# Name: median_house_value, dtype: float64

# %%
df_far["median_house_value"].describe()
# Out:
# count     17000.000000
# mean     207300.912353
# std      115983.764387
# min       14999.000000
# 25%      119400.000000
# 50%      180400.000000
# 75%      265000.000000
# max      500001.000000
# Name: median_house_value, dtype: float64

# %% [markdown]
# H0: Houses closer to a school or hospital are as expensive or cheaper than houses farther away.
# H1: Houses closer to a school or hospital are more expensive than houses farther away.
#
# alpha = 0.05

# %%
alpha = 0.05

# %%
t_stat, p_value = st.ttest_ind(df_close['median_house_value'], df_far['median_house_value'], equal_var=False, alternative = "greater" )

t_stat, p_value
# Out:
# (-17.169161722319306, 0.9999738667251178)

# %% [markdown]
# The t-test shows a p-value of 0.9999738667251178, meaning that we cannot reject the null hypothesis! Comparing the average median house prices of the far away and close houses actually shows the opposite, with farther away houses being on average more expensive. Furthermore, there were only 5 houses fitting the posited criterion for closeness and such a small sample size will result in a reduced power of our test and will contain a greater variability making it hard to infer robust conclusions about house prizes and their dependence on the distance to either a school or a hospital.
